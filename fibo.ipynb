# %% [markdown]
# <a href="https://colab.research.google.com/github/samyakjain2237/Btech_AI/blob/main/fibo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 0
b = 1
n = 5

for i in range(n):
    print(a)
    c = a + b
    a = b
    b = c
# Out:
# 0
# 1
# 1
# 2
# 3

# %%
def fibonacci(n):
    a = 0
    b = 1

    for i in range(n):
        print(a, end=" ")
        c = a + b
        a = b
        b = c

fibonacci(5)
# Out:
# 0 1 1 2 3
